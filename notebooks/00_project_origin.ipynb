# %% [markdown]
# # Project Origin
#
# This teaching notebook documents the transition from the University of Colorado Boulder assignment to the engineering platform. Exact original files are migrated into `legacy/`.

# %%
from cpathlab import __version__
print(__version__)
