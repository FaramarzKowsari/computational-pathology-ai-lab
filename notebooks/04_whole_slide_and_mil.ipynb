# %% [markdown]
# # Whole-Slide and MIL
#
# This notebook is ready for legally obtained WSI inputs and extracted feature bags.

# %%
from cpathlab.data.wsi import tissue_mask, iter_patches
from cpathlab.models.mil import AttentionMIL
