# %% [markdown]
# # Dataset Audit
#
# Run validation and leakage checks before training.

# %%
from cpathlab.data.validation import validate_dataset
# validate_dataset("data/example/images", "data/example/labels.csv")
